# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/content/gurgaon_properties_cleaned_v2.csv")

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
sns.displot(df['price'],kde = True)

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3677, 23)

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_sqft = df[(df['price']<lower_bound) | (df['price']>upper_bound)]
outliers_sqft['price'].describe()
# Out:
# count    425.000000
# mean       9.235624
# std        4.065259
# min        5.460000
# 25%        6.460000
# 50%        8.000000
# 75%       10.750000
# max       31.500000
# Name: price, dtype: float64

# %%
# Define the filter condition once
mask = (outliers_sqft['property_type'] == 'house') & (outliers_sqft['area'] <= 1000) & (outliers_sqft['floorNum'] > 0)

outliers_sqft.loc[mask, 'area'] = outliers_sqft[mask]['area'] * outliers_sqft[mask]['floorNum']

# %%
outliers_sqft[(outliers_sqft['property_type'] == 'house') & (outliers_sqft['area'] <= 1000) & (outliers_sqft['floorNum'] > 0)]
# Out:
#      property_type                      society      sector  price  \
# 342          house  unitech nirvana birch court   sector 50   7.10
# 386          house           cloudnine cottages  sohna road   5.50
# 545          house                  independent   sector 24  10.00
# 867          house                   ardee city   sector 52   5.50
# 1027         house                dlf the grove   sector 54   5.70
# 1259         house           vipul tatvam villa   sector 48   7.25
# 2161         house       dlf city plots phase 2   sector 25  10.50
# 2461         house                  independent   sector 12   6.00
# 2850         house       dlf city plots phase 2   sector 25  10.00
# 3015         house       unitech deerwood chase   sector 50   8.45
# 3046         house       emaar the palm springs   sector 54  24.00
# 3386         house                  independent   sector 38   8.00
# 3449         house                  independent   sector 57   8.00
#
# ...

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# /tmp/ipykernel_2045/205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count       425.000000
# mean      36456.475294
# std       51784.501266
# min        1560.000000
# 25%       19488.000000
# 50%       26389.000000
# 75%       35222.000000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
# 1. Define the mask for your new conditions
df_mask = (df['property_type'] == 'house') & (df['area'] <= 1000) & (df['floorNum'] <= 5) & (df['floorNum'] > 1)

# 2. Update the 'area' column directly using .loc
df.loc[df_mask, 'area'] = df.loc[df_mask, 'area'] * df.loc[df_mask, 'floorNum']

# 3. Recalculate and round 'price_per_sqft' for only those rows
df.loc[df_mask, 'price_per_sqft'] = ((df.loc[df_mask, 'price'] * 10000000) / df.loc[df_mask, 'area']).round()

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# /tmp/ipykernel_2045/2491436972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# /tmp/ipykernel_2045/2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society      sector  price  \
# 386          house            cloudnine cottages  sohna road   5.50
# 671          house            emaar mgf marbella   sector 66  18.00
# 1062         house                   independent   sector 23   2.80
# 1200         house                   independent   sector 26  14.75
# 1261         house                   independent   sector 25  16.00
# 1332         house             ansal api esencia   sector 67   1.85
# 1349          flat                unitech vistas   sector 70   9.00
# 1385         house      unitech uniworld resorts   sector 33   9.50
# 1425         house  project housing board colony   sector 31   8.00
# 1589         house                   independent    sector 7   1.00
# 1628         house          eros rosewood villas   sector 49   2.75
# 1640         house        emaar the palm springs   sector 54  14.00
# 1839         house                unitech escape   sector 50  10.80
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# # Area

# %%
sns.distplot(df['area'])
# Out:
# /tmp/ipykernel_2045/91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3628.000000
# mean       2954.566703
# std       23266.353189
# min          72.000000
# 25%        1300.000000
# 50%        1760.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 1638          flat  signature global solera 2  sector 107   0.51
# 1648          flat          hcbs sports ville  sohna road   0.35
# 2111          flat      signature the roselia   sector 95   0.45
# 2651          flat            ramsons kshitij   sector 95   0.31
# 3021         house                independent   sector 50   5.00
#
#       price_per_sqft      area                           areaWithType  \
# 1638             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 1648             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 2111             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 2651             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 3021           232.0  215517.0             Plot area 2(1011.71 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1638        2         2       1       3.0       North    New Property
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# /tmp/ipykernel_2045/91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 818          house                independent   sector 26  18.40
# 48           house  ganpati heights apartment   sector 13   1.25
# 1123          flat                 rof ananda   sector 95   0.38
# 1796          flat                 rof ananda   sector 95   0.38
# 300          house      dlf city plot phase 4   sector 28  13.00
# 2             flat              pyramid elite   sector 86   0.46
# 2356          flat                 rof ananda   sector 95   0.33
# 115           flat      signature the serenas  sohna road   0.28
# 2666         house                independent   sector 25   7.30
# 3649          flat            ramsons kshitij   sector 95   0.24
# 2503          flat                 rof ananda   sector 95   0.21
# 1358         house                independent   sector 57   6.25
# 3195         house                independent   sector 43   5.50
# ...

# %%
df.drop(index=[818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 48           house  ganpati heights apartment   sector 13   1.25
# 300          house      dlf city plot phase 4   sector 28  13.00
# 2666         house                independent   sector 25   7.30
# 1358         house                independent   sector 57   6.25
# 3195         house                independent   sector 43   5.50
# 2131          flat                 godrej air   sector 85   2.50
# 3088         house       unitech aspen greens   sector 50   6.95
# 3444          flat                godrej icon  sector 88a   1.75
# 2834         house                independent   sector 43  27.50
# 2342          flat             m3m golfestate   sector 65  13.20
# 747          house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 48             151.0  82781.0
# 300           1992.0  65261.0
# 2666          1560.0  46795.0
# 1358          2778.0  22498.0
# ...

# %%
df.loc[48,'area'] = 115*9
df.loc[300,'area'] = 7250
df.loc[2666,'area'] = 5800
df.loc[1358,'area'] = 2660
df.loc[3195,'area'] = 2850
df.loc[2131,'area'] = 1812
df.loc[3088,'area'] = 2160
df.loc[3444,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# /tmp/ipykernel_2045/91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3614.000000
# mean      1951.983121
# std       1172.663222
# min         72.000000
# 25%       1299.000000
# 50%       1760.000000
# 75%       2339.500000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# # Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# /tmp/ipykernel_2045/1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3614.000000
# mean        3.325955
# std         1.816066
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 3618         house                  independent   sector 54   5.00
# 2611         house                  independent   sector 43   4.50
# 78           house                  independent   sector 17   3.87
# 1493         house                  independent   sector 17   3.93
# 1381         house                private house   sector 55   7.05
# 19           house                  independent   sector 54   5.50
# 2137         house                  independent   sector 40  12.00
# 874          house               dlf city plots   sector 26  20.00
# 2039         house                  independent   sector 43  13.50
# 3457         house                  independent   sector 56  12.39
# 372          house                  independent   sector 11   4.50
# 3698         house                  independent   sector 55   9.19
# 2096         house       luxury dlf city floors   sector 26  20.00
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
sns.distplot(df['bedRoom'])
# Out:
# /tmp/ipykernel_2045/1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3571.000000
# mean        3.200784
# std         1.391152
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# # Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# /tmp/ipykernel_2045/2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 3267         house  adani brahma samsara  sector 60  18.02         28200.0
# 2771         house           independent  sector 39   7.00         10000.0
# 2816         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 3267  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 2771  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 2816  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3267        12      3+       3.0  North-East  Relatively New
# 2771        11      3+       4.0  South-East  Relatively New
# 2816        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %% [markdown]
# # Super Built Area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# /tmp/ipykernel_2045/4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1323          flat  bestech park view grand spa    sector 81    4.7
# 3265          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1323          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3265          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1323        4         4      3+      19.0       North  Relatively New
# 3265        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1323               6926.0            NaN          NaN           0
# 3265              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %%
sns.distplot(df['built_up_area'])
# Out:
# /tmp/ipykernel_2045/3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 2834         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2834  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 2834  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2834          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 2834                1            42

# %%
sns.distplot(df['carpet_area'])
# Out:
# /tmp/ipykernel_2045/3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2131          flat      godrej air  sector 85    2.5          1379.0   1812.0
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2131  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 2342  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 2131  North-East  Under Construction                  NaN            NaN
# 2342       North      Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2131      18122.0           1             0           0           1       1
# 2342      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[2131,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2342  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 2342  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 2342           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 2342                0            60

# %%
sns.distplot(df['luxury_score'])
# Out:
# /tmp/ipykernel_2045/3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])
# Out:
# /tmp/ipykernel_2045/3958460563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# /tmp/ipykernel_2045/2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 90           house                   independent  sector 105   0.50
# 666          house                   independent    sector 4   0.58
# 711          house                   independent   sector 26  20.00
# 901          house                   independent   sector 28  12.00
# 1090         house                   independent  sector 105   9.90
# 1509         house                   independent   sector 55   5.00
# 1526         house                dlf city plots   sector 26  19.00
# 1627         house                   independent  sector 105   0.55
# 2040         house                   independent   sector 43   9.50
# 2056          flat        breez global hill view  sohna road   2.60
# 2088         house                   independent   sector 12   3.50
# 2130         house                   independent   sector 26  19.00
# 2297          flat                      lig flat   sector 40   1.50
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02)
# Out:
# np.float64(233.76)

# %%
df[(df['area']/df['bedRoom'])<234]
# Out:
#      property_type                                 society      sector  price  \
# 9            house                             independent  sector 105   1.20
# 48           house               ganpati heights apartment   sector 13   1.25
# 74           house                             independent   sector 25   7.60
# 90           house                             independent  sector 105   0.50
# 93           house                             independent  sector 105   1.10
# ...            ...                                     ...         ...    ...
# 3633         house                             independent   sector 17   0.32
# 3693         house                            malibu towne   sector 47   1.15
# 3713         house                             independent   sector 41   4.25
# 3751         house                             independent   sector 21   0.45
# 3797         house  surendra homes dayaindependentd colony    sector 6   0.75
#
# ...

# %%
sns.lmplot(data = df,x = 'area',y='bedRoom')

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']
# Out:
# /tmp/ipykernel_2045/465686754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df = df[df['area_room_ratio']>100]

# %%
outliers_df = df[(df['area_room_ratio']<234)&(df['bedRoom']>3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# /tmp/ipykernel_2045/3450078040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']
# Out:
# /tmp/ipykernel_2045/465686754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<250)&(df['bedRoom']>4)]
# Out:
#      property_type                    society      sector  price  \
# 93           house                independent  sector 105   1.10
# 255          house             uppal southend   sector 49   3.75
# 387          house                independent   sector 12   0.65
# 565          house    iffco nagar and 17b rwa   sector 17   3.50
# 753          house                   shivpuri    sector 7   2.80
# 1087         house                independent   sector 47   4.30
# 1106         house                independent    sector 5   0.85
# 1206         house                independent    sector 7   1.16
# 1747         house                independent   sector 12   2.50
# 1936         house                independent   sector 11   3.50
# 1939         house                independent     manesar   1.10
# 2333         house         unitech south city   sector 50   5.88
# 2386         house                independent   sector 47   4.60
# ...

# %%
df = df[~((df['area_room_ratio']<250)&(df['bedRoom']>4))]

# %%
sns.lmplot(data = df , x = 'area',y='bedRoom')

# %%
df.to_csv('grugaon_properties_outlier_treated.csv',index = False)
