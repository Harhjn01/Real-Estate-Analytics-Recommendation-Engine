# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv("/content/grugaon_properties_outlier_treated.csv")

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat       breez global hill view  sohna road   0.32
# 3          flat  bestech park view sanskruti   sector 92   1.60
# 4          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7586.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8597.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 3          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 4          9023.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 0        3         2       2       2.0         NaN    New Property
# 1        2         2       2       4.0         NaN    New Property
# 2        2         2       1      17.0         NaN    New Property
# 3        3         4      3+      10.0  North-West  Relatively New
# 4        2         2       1       5.0  North-East  Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1081.0            NaN        650.0           0             0
# 1                  NaN            NaN       1103.0           1             1
# 2                  NaN         1000.0        585.0           0             0
# 3               1995.0         1615.0       1476.0           0             1
# 4                632.0            NaN        532.0           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score  \
# 0           0           0       0                0             8
# 1           0           0       0                0            38
# 2           0           0       0                0            49
# 3           0           0       1                1           174
# 4           1           0       0                0           159
#
#    area_room_ratio
# 0       360.333333
# 1       552.500000
# 2       292.500000
# 3       665.000000
# 4       266.000000

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1004
# agePossession             0
# super_built_up_area    1659
# built_up_area          1966
# carpet_area            1700
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# Built Up Area

# %%
sns.scatterplot(data=df, x='built_up_area', y='super_built_up_area')
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
sns.scatterplot(data=df, x='built_up_area', y='carpet_area')
# Out:
# <Axes: xlabel='built_up_area', ylabel='carpet_area'>

# %%
all_present_df = df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df.shape
# Out:
# (531, 24)

# %%
super_to_built_up_ratio = (all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_to_built_up_ratio = (all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_to_built_up_ratio, carpet_to_built_up_ratio)
# Out:
# 1.105263157894737 0.9

# %%
sbc_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# /tmp/ipykernel_14991/1215074969.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# /tmp/ipykernel_14991/1215074969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)

# %%
df.update(sbc_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1004
# agePossession             0
# super_built_up_area    1659
# built_up_area          1545
# carpet_area            1700
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
# sb present c is null built up null
sb_df = df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# Out:
# /tmp/ipykernel_14991/1714170073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# /tmp/ipykernel_14991/1714170073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)

# %%
df.update(sb_df)

# %%
# sb null c is present built up null
c_df = df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# /tmp/ipykernel_14991/2136919732.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# /tmp/ipykernel_14991/2136919732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)

# %%
df.update(c_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 17
# facing                 1004
# agePossession             0
# super_built_up_area    1659
# built_up_area             0
# carpet_area            1700
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(data = df , x = 'built_up_area', y = 'price')
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anamoly_df = df[(df['built_up_area'] < 2000) & (df['price'] > 2.5)][['price','area','built_up_area']]

# %%
anamoly_df.sample(5)
# Out:
#       price    area  built_up_area
# 283   11.30  4500.0          480.0
# 2555   3.67  2040.0         1846.0
# 1163   3.25  2072.0         1875.0
# 2234   3.10  1500.0         1667.0
# 381    6.50  1800.0         1800.0

# %%
anamoly_df['built_up_area'] = anamoly_df['area']

# %%
df.update(anamoly_df)

# %%
sns.scatterplot(data = df,x = 'built_up_area',y = 'price')
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum             17
# facing             1004
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxury_score          0
# dtype: int64

# %% [markdown]
# # Floor No

# %%
df[df['floorNum'].isnull()]
# Out:
#      property_type                  society             sector  price  \
# 500          house              independent           sector 4   0.65
# 766          house              independent           sector 7   6.50
# 1289         house              independent           sector 3   1.50
# 1447         house       vipul tatvam villa          sector 48   8.50
# 1460         house  ansal sushant lok plots          sector 43   3.30
# 1938         house               jacob pura          sector 12   0.35
# 2039         house       vipul tatvam villa          sector 48   8.50
# 2146         house              independent           sector 4   4.12
# 2260         house       emaar mgf marbella          sector 66   9.00
# 2426         house     dlf new town heights          sector 86   2.47
# 2522          flat                      NaN          sector 78   0.60
# 2531         house        ansal sushant lok          sector 43  10.50
# 2901         house              independent          sector 25  13.00
# 2949         house              independent          sector 24   1.45
# 3101         house              independent          sector 26   4.60
# 3194          flat       experion heartsong  dwarka expressway   1.08
# 3235         house              independent           sector 2   5.60
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 500          11111.0        4         2       2       NaN         NaN
# 766          15046.0        3         2      3+       NaN         NaN
# 1289         10288.0        3         3       0       NaN         NaN
# 1447         26235.0        4         4       1       NaN         NaN
# 1460         26570.0        1         1       0       NaN         NaN
# 1938          9722.0        2         1       0       NaN         NaN
# 2039         26235.0        4         4       2       NaN        East
# 2146          8889.0        2         1      3+       NaN         NaN
# 2260         21251.0        4         4      3+       NaN  South-West
# 2426          7719.0        4         4      3+       NaN        West
# 2522          3692.0        2         2       0       NaN         NaN
# 2531         27911.0        4         4       2       NaN  North-East
# 2901         45710.0        6         8      3+       NaN         NaN
# 2949         26852.0        3         3       1       NaN         NaN
# 3101         12198.0        4         4      3+       NaN         NaN
# 3194          6150.0        3         3       0       NaN         NaN
# 3235         17284.0        8         6      3+       NaN  South-West
#
#            agePossession  built_up_area  study room  servant room  store room  \
# 500       Moderately Old          585.0           0             0           0
# 766         Old Property         4320.0           0             0           0
# 1289        Old Property          210.0           0             0           0
# 1447      Relatively New         3240.0           0             0           0
# 1460  Under Construction         1242.0           0             0           0
# 1938        Old Property          360.0           0             0           0
# 2039      Moderately Old         3240.0           0             1           1
# 2146      Moderately Old         4635.0           0             0           0
# 2260      Relatively New         5200.0           0             1           1
# 2426      Moderately Old         2800.0           0             1           0
# 2522  Under Construction         1625.0           0             0           0
# 2531        Old Property         3762.0           0             1           0
# 2901      Relatively New         2844.0           1             1           1
# 2949        Old Property          540.0           0             0           0
# 3101        Old Property         3771.0           0             0           0
# 3194  Under Construction         1758.0           0             0           0
# 3235      Moderately Old         3240.0           1             1           1
#
#       pooja room  others  furnishing_type  luxury_score
# 500            0       0                0             0
# 766            0       0                0             9
# 1289           0       0                0             0
# 1447           0       0                0            21
# 1460           0       0                0             0
# 1938           0       0                0             0
# 2039           1       0                0            88
# 2146           0       0                0             0
# 2260           1       0                1           114
# 2426           1       0                1           130
# 2522           0       0                0             0
# 2531           0       0                0            59
# 2901           1       0                2             0
# 2949           0       0                0             9
# 3101           0       0                0            28
# 3194           0       0                0             0
# 3235           1       0                0             0

# %%
df[df['property_type'] == 'house']['floorNum'].median()
# Out:
# 2.0

# %%
df['floorNum'].fillna(2.0,inplace=True)
# Out:
# /tmp/ipykernel_14991/3788705936.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['floorNum'].fillna(2.0,inplace=True)

# %% [markdown]
# # Facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.drop(columns=['facing'],inplace=True)

# %%
df[df['society'].isna()]
# Out:
#      property_type society     sector  price  price_per_sqft  bedRoom  \
# 2522          flat     NaN  sector 78    0.6          3692.0        2
#
#       bathroom balcony  floorNum       agePossession  built_up_area  \
# 2522         2       0       2.0  Under Construction         1625.0
#
#       study room  servant room  store room  pooja room  others  \
# 2522           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 2522                0             0

# %%
df.drop(index=[2522],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat       breez global hill view  sohna road   0.32
# 3          flat  bestech park view sanskruti   sector 92   1.60
# 4          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 0          7586.0        3         2       2       2.0    New Property
# 1          8597.0        2         2       2       4.0    New Property
# 2          5470.0        2         2       1      17.0    New Property
# 3          8020.0        3         4      3+      10.0  Relatively New
# 4          9023.0        2         2       1       5.0  Relatively New
#
#    built_up_area  study room  servant room  store room  pooja room  others  \
# 0          850.0           0             0           0           0       0
# 1         1226.0           1             1           0           0       0
# 2         1000.0           0             0           0           0       0
# 3         1615.0           0             1           0           0       1
# 4          582.0           0             0           1           0       0
#
#    furnishing_type  luxury_score
# 0                0             8
# 1                0            38
# 2                0            49
# 3                1           174
# 4                0           159

# %% [markdown]
# # Age Possession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1600
# New Property           559
# Moderately Old         539
# Old Property           288
# Undefined              285
# Under Construction     262
# Name: count, dtype: int64

# %%
df[df['agePossession'] == 'Undefined']
# Out:
#      property_type                                 society      sector  price  \
# 10           house                             independent  sector 109   1.55
# 33           house                             greenopolis   sector 89   0.70
# 49            flat                        smart world gems   sector 89   1.71
# 71            flat                             rof aalayas  sector 102   0.45
# 75           house                         bhim garh kheri    sector 3   1.50
# ...            ...                                     ...         ...    ...
# 3476          flat                         raheja vedaanta  sector 108   0.70
# 3481          flat                   signature global city  sector 37d   1.10
# 3487         house                             independent   sector 21   0.45
# 3499          flat                       sidhartha ncr one   sector 95   0.57
# 3528         house  surendra homes dayaindependentd colony    sector 6   0.75
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum agePossession  \
# 10            6568.0        3         2       0       1.0     Undefined
# 33            5397.0        2         2       2      14.0     Undefined
# 49           12000.0        3         2       0       3.0     Undefined
# 71            6000.0        1         1       2       6.0     Undefined
# 75            7576.0        7         2       0       1.0     Undefined
# ...              ...      ...       ...     ...       ...           ...
# 3476          4522.0        2         2       3       1.0     Undefined
# 3481          9839.0        2         2       2       4.0     Undefined
# 3487          8411.0        3         2       1       1.0     Undefined
# 3499          4179.0        2         2       2      10.0     Undefined
# 3528         15625.0        4         4       2       1.0     Undefined
#
#       built_up_area  study room  servant room  store room  pooja room  others  \
# 10           2360.0           0             0           0           0       0
# 33           1297.0           0             0           0           0       0
# 49           1423.0           0             0           0           0       0
# 71            750.0           0             0           0           0       0
# 75           1980.0           0             0           0           0       0
# ...             ...         ...           ...         ...         ...     ...
# 3476         1548.0           0             0           0           0       0
# 3481         1242.0           0             0           0           0       0
# 3487          594.0           0             0           0           0       0
# 3499         1364.0           0             0           0           0       0
# 3528          480.0           0             0           0           0       0
#
#       furnishing_type  luxury_score
# 10                  0             0
# 33                  0             0
# 49                  0            45
# 71                  0             0
# 75                  0             0
# ...               ...           ...
# 3476                0             0
# 3481                0            59
# 3487                0             0
# 3499                0             0
# 3528                0             0
#
# [285 rows x 18 columns]

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1706
# New Property           600
# Moderately Old         584
# Old Property           316
# Under Construction     276
# Undefined               51
# Name: count, dtype: int64

# %%
def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1720
# New Property           601
# Moderately Old         595
# Old Property           326
# Under Construction     276
# Undefined               15
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0]
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1722
# Moderately Old         608
# New Property           601
# Old Property           326
# Under Construction     276
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxury_score       0
# dtype: int64

# %%
df.to_csv('gurgaon_properties_missing_value_imputation.csv',index=False)

# %%
df.shape
# Out:
# (3533, 18)
